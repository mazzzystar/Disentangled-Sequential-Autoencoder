# %%
from PIL import Image
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torchvision.transforms as T

# %%
im = Image.open("test.png")

# %%
plt.imshow(im)

# %%
image = np.array(im)

# %%
plt.imshow(im)

# %%
image.shape
# Out:
# (1344, 832, 4)

# %%
frame1 = image[64*9:64*10,64:64*2,:]
frame1.shape
# Out:
# (64, 64, 4)

# %%
plt.imshow(frame1)

# %%
1344/64
# Out:
# 21.0

# %%
832/64
# Out:
# 13.0
